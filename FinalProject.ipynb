# %%
import pandas as pd
import numpy as np
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %%
cities=pd.read_csv("C:\\Users\\srini\\Desktop\\ PythonProjects\\cities_r2.csv")

# %%
cities.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# 1                 6186                   5624  ...             43086
# 2                 6731                   6372  ...             37660
# 3                12063                  10979  ...             54515
# 4                 9355                   9051  ...             45089
#
#    sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 0        890              848                          79.86
# 1        928              909                          91.99
# 2        982              947                          80.51
# 3        902              910                          83.46
# 4       1013              968                          68.38
#
#    effective_literacy_rate_male  effective_literacy_rate_female  \
# 0                         85.49                           73.59
# 1                         94.77                           89.00
# 2                         88.18                           72.73
# 3                         89.98                           76.23
# 4                         76.58                           60.33
#
#                 location  total_graduates male_graduates  female_graduates
# 0  30.1452928,74.1993043            16287           8612              7675
# 1   21.257584,77.5086754             8863           5269              3594
# 2   19.0809075,79.560344            10565           6797              3768
# 3  22.7834741,86.1576889            19225          12189              7036
# 4  15.6322227,77.2728368            11902           7871              4031
#
# [5 rows x 22 columns]

# %%
pwd
# Out:
# 'C:\\Users\\srini\\Desktop\\ PythonProjects'

# %%
cities.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# 25%         6.041100e+04          1.363900e+04          7221.000000
# 50%         8.776800e+04          1.944000e+04         10342.000000
# 75%         1.700260e+05          3.794500e+04         19982.000000
# max         5.741632e+06          1.209275e+06        647938.000000
#
#        0-6_population_female  literates_total  literates_male  \
# count             493.000000     4.930000e+02    4.930000e+02
# mean            22243.320487     3.461527e+05    1.894384e+05
# std             49523.241379     8.220952e+05    4.534753e+05
# min              3107.000000     5.699800e+04    3.475100e+04
# 25%              6457.000000     9.768700e+04    5.357800e+04
# 50%              9172.000000     1.413290e+05    7.590600e+04
# 75%             17954.000000     2.679000e+05    1.455480e+05
# max            561337.000000     1.023759e+07    5.727774e+06
#
#        literates_female    sex_ratio  child_sex_ratio  \
# count      4.930000e+02   493.000000       493.000000
# mean       1.567143e+05   930.294118       902.332657
# std        3.690677e+05    55.849106        49.794689
# min        2.224700e+04   700.000000       762.000000
# 25%        4.391400e+04   890.000000       868.000000
# 50%        6.383600e+04   922.000000       903.000000
# 75%        1.235030e+05   971.000000       942.000000
# max        4.509812e+06  1093.000000      1185.000000
#
#        effective_literacy_rate_total  effective_literacy_rate_male  \
# count                     493.000000                    493.000000
# mean                       85.131460                     89.920162
# std                         6.186345                      5.377492
# min                        49.510000                     52.270000
# 25%                        81.750000                     87.280000
# 50%                        85.970000                     91.180000
# 75%                        89.330000                     93.400000
# max                        98.800000                     99.300000
#
#        effective_literacy_rate_female  total_graduates  male_graduates  \
# count                      493.000000     4.930000e+02    4.930000e+02
# mean                        79.967181     6.620236e+04    3.771556e+04
# std                          7.577825     1.778187e+05    9.849574e+04
# min                         46.450000     2.532000e+03    1.703000e+03
# 25%                         75.800000     1.527700e+04    9.289000e+03
# 50%                         80.920000     2.395900e+04    1.404900e+04
# 75%                         85.400000     5.036700e+04    2.787200e+04
# max                         98.310000     2.221137e+06    1.210040e+06
#
#        female_graduates
# count      4.930000e+02
# mean       2.848680e+04
# std        7.951556e+04
# min        8.290000e+02
# 25%        6.114000e+03
# 50%        9.558000e+03
# 75%        2.086600e+04
# max        1.011097e+06

# %%
cities.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b01a618077b9> in <module>
# ----> 1 cities.head()
#
# NameError: name 'cities' is not defined

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\srini\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\srini\anaconda3\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: branca>=0.3.0 in c:\users\srini\anaconda3\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in c:\users\srini\anaconda3\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: numpy in c:\users\srini\anaconda3\lib\site-packages (from folium) (1.19.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\srini\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\srini\anaconda3\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\srini\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\srini\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\srini\anaconda3\lib\site-packages (from requests->folium) (1.25.11)

# %%
m_1 = folium.Map(location=[20.5936832,78.962883], tiles='cartodbpositron', zoom_start=5)

# Add points to the map
for idx, row in uttarpradesh.iterrows():
    Marker([row['lattitude'], row['longitude']]).add_to(m_1)

# Display the map
m_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d135fb58104a> in <module>
# ----> 1 m_1 = folium.Map(location=[20.5936832,78.962883], tiles='cartodbpositron', zoom_start=5)
#       2
#       3 # Add points to the map
#       4 for idx, row in uttarpradesh.iterrows():
#       5     Marker([row['lattitude'], row['longitude']]).add_to(m_1)
#
# NameError: name 'folium' is not defined

# %%
state_graduates  = cities[["state_name","total_graduates","male_graduates","female_graduates"]].groupby("state_name").agg({"total_graduates":np.average,"male_graduates":np.average,"female_graduates":np.average})
state_graduates.sort_values("total_graduates", ascending=True).plot(kind="barh",grid=True,figsize=(16,15),alpha = 0.6,width=0.6,stacked = False,edgecolor="g",fontsize = 20)
plt.grid(b=True, which='both')
plt.legend()
plt.show ()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2b6eb5850c5a> in <module>
# ----> 1 state_graduates  = cities[["state_name","total_graduates","male_graduates","female_graduates"]].groupby("state_name").agg({"total_graduates":np.average,"male_graduates":np.average,"female_graduates":np.average})
#       2 state_graduates.sort_values("total_graduates", ascending=True).plot(kind="barh",grid=True,figsize=(16,15),alpha = 0.6,width=0.6,stacked = False,edgecolor="g",fontsize = 20)
#       3 plt.grid(b=True, which='both')
#       4 plt.legend()
#       5 plt.show ()
#
# NameError: name 'cities' is not defined

# %%
m_1 = folium.Map(location=[20.5936832,78.962883], tiles='cartodbpositron', zoom_start=5)

# Add points to the map
for idx, row in uttarpradesh.iterrows():
    Marker([row['lattitude'], row['longitude']]).add_to(m_1)

# Display the map
m_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d135fb58104a> in <module>
# ----> 1 m_1 = folium.Map(location=[20.5936832,78.962883], tiles='cartodbpositron', zoom_start=5)
#       2
#       3 # Add points to the map
#       4 for idx, row in uttarpradesh.iterrows():
#       5     Marker([row['lattitude'], row['longitude']]).add_to(m_1)
#
# NameError: name 'folium' is not defined

# %%
m_2 = folium.Map(location=[20.5936832,78.962883], tiles='cartodbpositron', zoom_start=5)

# Add points to the map
for idx, row in graduates_above_1lakh.iterrows():
    Marker([row['lattitude'], row['longitude']]).add_to(m_2)

# Display the map
m_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-bcbf47139e84> in <module>
# ----> 1 m_2 = folium.Map(location=[20.5936832,78.962883], tiles='cartodbpositron', zoom_start=5)
#       2
#       3 # Add points to the map
#       4 for idx, row in graduates_above_1lakh.iterrows():
#       5     Marker([row['lattitude'], row['longitude']]).add_to(m_2)
#
# NameError: name 'folium' is not defined

# %%
import folium

london_location = [51.507351, -0.127758]

m = folium.Map(location=london_location, zoom_start=15)
m
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-de4a790d8bae> in <module>
# ----> 1 import folium
#       2
#       3 london_location = [51.507351, -0.127758]
#       4
#       5 m = folium.Map(location=london_location, zoom_start=15)
#
# ~\anaconda3\lib\site-packages\folium\__init__.py in <module>
#       3 import sys
#       4
# ----> 5 import branca
#       6 from branca.colormap import (ColorMap, LinearColormap, StepColormap)
#       7 from branca.element import (
#
# ~\anaconda3\lib\site-packages\branca\__init__.py in <module>
# ----> 1 import branca.colormap as colormap
#       2 import branca.element as element
#       3
#       4 from ._version import get_versions
#       5
#
# ~\anaconda3\lib\site-packages\branca\colormap.py in <module>
#      13 from jinja2 import Template
#      14
# ---> 15 from branca.element import ENV, Figure, JavascriptLink, MacroElement
#      16 from branca.utilities import legend_scaler
#      17
#
# ~\anaconda3\lib\site-packages\branca\element.py in <module>
#      17 from jinja2 import Environment, PackageLoader, Template
#      18
# ---> 19 from .utilities import _camelify, _parse_size, none_max, none_min
#      20
#      21 ENV = Environment(loader=PackageLoader('branca', 'templates'))
#
# ~\anaconda3\lib\site-packages\branca\utilities.py in <module>
#      17
#      18 try:
# ---> 19     import pandas as pd
#      20 except ImportError:
#      21     pd = None
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in <module>
#     175
#     176 from pandas.util._tester import test
# --> 177 import pandas.testing
#     178 import pandas.arrays
#     179
#
# ~\anaconda3\lib\site-packages\pandas\testing.py in <module>
#       3 """
#       4
# ----> 5 from pandas._testing import (
#       6     assert_extension_array_equal,
#       7     assert_frame_equal,
#
# ~\anaconda3\lib\site-packages\pandas\_testing.py in <module>
#    2904
#    2905
# -> 2906 cython_table = pd.core.base.SelectionMixin._cython_table.items()
#    2907
#    2908
#
# AttributeError: partially initialized module 'pandas' has no attribute 'core' (most likely due to a circular import)
